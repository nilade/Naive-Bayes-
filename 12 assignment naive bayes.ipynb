# %% [markdown]
# # Q1 (SalaryData_Train)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB

# %%
sdtrain=pd.read_csv("SalaryData_Train.csv")
sdtrain
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
sdtest=pd.read_csv("SalaryData_Test.csv")
sdtest
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
sdtrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
sdtest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
sdtrain.shape
# Out:
# (30161, 14)

# %%
sdtest.shape
# Out:
# (15060, 14)

# %%
sdtrain.isna().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
sdtest.isna().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
sdtrain[sdtrain.duplicated()]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 326     33   Private      Bachelors           13   Married-civ-spouse
# 364     27   Private      Bachelors           13        Never-married
# 518     24   Private        HS-grad            9        Never-married
# 525     24   Private        HS-grad            9        Never-married
# 619     33   Private      Bachelors           13   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 30110   47   Private        HS-grad            9   Married-civ-spouse
# 30118   20   Private        HS-grad            9        Never-married
# 30132   22   Private   Some-college           10        Never-married
# 30157   40   Private        HS-grad            9   Married-civ-spouse
# 30159   22   Private        HS-grad            9        Never-married
#
#                occupation    relationship    race      sex  capitalgain  \
# ...

# %%
sdtest[sdtest.duplicated()]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 551     59   Private        HS-grad            9             Divorced
# 601     32   Private        HS-grad            9   Married-civ-spouse
# 681     40   Private        HS-grad            9   Married-civ-spouse
# 799     24   Private      Bachelors           13        Never-married
# 1044    44   Private    Prof-school           15   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 15043   51   Private        HS-grad            9   Married-civ-spouse
# 15044   22   Private   Some-college           10        Never-married
# 15049   32   Private        HS-grad            9   Married-civ-spouse
# 15052   31   Private        HS-grad            9   Married-civ-spouse
# 15053   25   Private        HS-grad            9        Never-married
#
#                occupation    relationship    race      sex  capitalgain  \
# ...

# %%
sdtrain.duplicated().sum()
# Out:
# 3258

# %%
sdtest.duplicated().sum()
# Out:
# 930

# %%
sdtrain1=sdtrain.drop_duplicates()
sdtrain1
# Out:
#        age          workclass      education  educationno  \
# 0       39          State-gov      Bachelors           13
# 1       50   Self-emp-not-inc      Bachelors           13
# 2       38            Private        HS-grad            9
# 3       53            Private           11th            7
# 4       28            Private      Bachelors           13
# ...    ...                ...            ...          ...
# 30154   53            Private        Masters           14
# 30155   22            Private   Some-college           10
# 30156   27            Private     Assoc-acdm           12
# 30158   58            Private        HS-grad            9
# 30160   52       Self-emp-inc        HS-grad            9
#
#              maritalstatus          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
sdtest1=sdtest.drop_duplicates()
sdtest1
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
sdtrain1.shape
# Out:
# (26903, 14)

# %%
sdtest1.shape
# Out:
# (14130, 14)

# %%
sdtrain1.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  26903.000000  26903.000000  26903.000000  26903.000000  26903.000000
# mean      39.049140     10.144296   1215.443259     98.427499     41.164591
# std       13.188825      2.620154   7805.366384    425.493211     12.347051
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       29.000000      9.000000      0.000000      0.000000     40.000000
# 50%       38.000000     10.000000      0.000000      0.000000     40.000000
# 75%       48.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %%
sdtest1.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  14130.000000  14130.000000  14130.000000  14130.000000  14130.000000
# mean      39.155414     10.120736   1185.899292     94.499646     41.073885
# std       13.429544      2.602557   7903.191981    417.955786     12.268036
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       29.000000      9.000000      0.000000      0.000000     40.000000
# 50%       38.000000     10.000000      0.000000      0.000000     40.000000
# 75%       48.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   3770.000000     99.000000

# %%
sdtrain1.corr()
# Out:
#                    age  educationno  capitalgain  capitalloss  hoursperweek
# age           1.000000     0.038048     0.077235     0.052684      0.072529
# educationno   0.038048     1.000000     0.126085     0.080025      0.145491
# capitalgain   0.077235     0.126085     1.000000    -0.036023      0.079403
# capitalloss   0.052684     0.080025    -0.036023     1.000000      0.049093
# hoursperweek  0.072529     0.145491     0.079403     0.049093      1.000000

# %%
sdtest1.corr()
# Out:
#                    age  educationno  capitalgain  capitalloss  hoursperweek
# age           1.000000     0.021979     0.076765     0.053172      0.088090
# educationno   0.021979     1.000000     0.132346     0.085651      0.127779
# capitalgain   0.076765     0.132346     1.000000    -0.033929      0.089512
# capitalloss   0.053172     0.085651    -0.033929     1.000000      0.056353
# hoursperweek  0.088090     0.127779     0.089512     0.056353      1.000000

# %%
sdtrain1.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
sdtest1.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
string_columns=['workclass','education','maritalstatus','occupation','relationship','race','sex','native']
string_columns
# Out:
# ['workclass',
#  'education',
#  'maritalstatus',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native']

# %%
label_encoder=preprocessing.LabelEncoder()
label_encoder
# Out:
# LabelEncoder()

# %%
for i in string_columns:
    sdtrain1[i]=label_encoder.fit_transform(sdtrain1[i])
    sdtest1[i]=label_encoder.fit_transform(sdtest1[i])
# Out:
# <ipython-input-26-f0a85fd51a7e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdtrain1[i]=label_encoder.fit_transform(sdtrain1[i])
# <ipython-input-26-f0a85fd51a7e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdtest1[i]=label_encoder.fit_transform(sdtest1[i])

# %%
col_names=list(sdtrain1.columns)
col_names
# Out:
# ['age',
#  'workclass',
#  'education',
#  'educationno',
#  'maritalstatus',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capitalgain',
#  'capitalloss',
#  'hoursperweek',
#  'native',
#  'Salary']

# %%
train_X=sdtrain1[col_names[0:13]]
train_X
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30154   53          2         12           14              2           3
# 30155   22          2         15           10              4          10
# 30156   27          2          7           12              2          12
# 30158   58          2         11            9              6           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# ...

# %%
train_Y=sdtrain1[col_names[13]]
train_Y
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 30154      >50K
# 30155     <=50K
# 30156     <=50K
# 30158     <=50K
# 30160      >50K
# Name: Salary, Length: 26903, dtype: object

# %%
# plotting pairplot
sns.pairplot(train_X)

# %%
col_names=list(sdtrain1.columns)
col_names
# Out:
# ['age',
#  'workclass',
#  'education',
#  'educationno',
#  'maritalstatus',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capitalgain',
#  'capitalloss',
#  'hoursperweek',
#  'native',
#  'Salary']

# %%
test_x=sdtest1[col_names[0:13]]
test_x
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# ...

# %%
test_y=sdtest1[col_names[13]]
test_y
# Out:
# 0         <=50K
# 1         <=50K
# 2          >50K
# 3          >50K
# 4         <=50K
#           ...
# 15055     <=50K
# 15056     <=50K
# 15057     <=50K
# 15058     <=50K
# 15059      >50K
# Name: Salary, Length: 14130, dtype: object

# %%
# plotting pairplot
sns.pairplot(test_x)

# %% [markdown]
# # **Naive Bayes**

# %% [markdown]
# **Gaussian Naive Bayes**

# %%
Gmodel=GaussianNB()
train_pred_gau=Gmodel.fit(train_X,train_Y).predict(train_X)
test_pred_gau=Gmodel.fit(train_X,train_Y).predict(test_x)

# %%
Gmodel
# Out:
# GaussianNB()

# %%
train_pred_gau
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       dtype='<U6')

# %%
test_pred_gau
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' >50K', ' <=50K'],
#       dtype='<U6')

# %%
train_acc_gau=np.mean(train_pred_gau==train_Y)
test_acc_gau=np.mean(test_pred_gau==test_y)
train_acc_gau#0.795
test_acc_gau#0.794
# Out:
# 0.7951875442321302

# %%
pd.crosstab(train_pred_gau,train_acc_gau)
# Out:
# col_0   0.793369
# row_0
#  <=50K     23418
#  >50K       3485

# %%
pd.crosstab(train_pred_gau,train_acc_gau).plot(kind="bar", figsize=(10, 5))
# Out:
# <AxesSubplot:xlabel='row_0'>

# %%
pd.crosstab(test_pred_gau,test_acc_gau)
# Out:
# col_0   0.795188
# row_0
#  <=50K     12386
#  >50K       1744

# %%
pd.crosstab(test_pred_gau,test_acc_gau).plot(kind="bar", figsize=(10, 5))
# Out:
# <AxesSubplot:xlabel='row_0'>

# %% [markdown]
# **Multinomial Naive Bayes**

# %%
Mmodel=MultinomialNB()
train_pred_multi=Mmodel.fit(train_X,train_Y).predict(train_X)
test_pred_multi=Mmodel.fit(train_X,train_Y).predict(test_x)

# %%
Mmodel
# Out:
# MultinomialNB()

# %%
train_pred_multi
# Out:
# array([' >50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       dtype='<U6')

# %%
test_pred_multi
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' >50K', ' <=50K'],
#       dtype='<U6')

# %%
train_acc_multi=np.mean(train_pred_multi==train_Y)
test_acc_multi=np.mean(test_pred_multi==test_y)
train_acc_multi#0.772
test_acc_multi#0.774
# Out:
# 0.7733899504600141

# %%
pd.crosstab(train_pred_multi,train_acc_multi)
# Out:
# col_0   0.768316
# row_0
#  <=50K     24386
#  >50K       2517

# %%
pd.crosstab(train_pred_multi,train_acc_multi).plot(kind="bar", figsize=(10, 5))
# Out:
# <AxesSubplot:xlabel='row_0'>

# %%
pd.crosstab(test_pred_multi,test_acc_multi)
# Out:
# col_0   0.77339
# row_0
#  <=50K    12884
#  >50K      1246

# %%
pd.crosstab(test_pred_multi,test_acc_multi).plot(kind="bar", figsize=(10, 5))
# Out:
# <AxesSubplot:xlabel='row_0'>
